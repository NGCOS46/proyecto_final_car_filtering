# %%
import pandas as pd
import re
# Specify the file paths for each CSV file
spain_csv_path = r'C:\Users\VANT\iron\proyectos\PROYECTO_FINAL\previos a limpieza\austria_df.csv'
germany_csv_path = r'C:\Users\VANT\iron\proyectos\PROYECTO_FINAL\previos a limpieza\germany_df.csv'
italy_csv_path = r'C:\Users\VANT\iron\proyectos\PROYECTO_FINAL\previos a limpieza\italy_df.csv'
france_csv_path = r'C:\Users\VANT\iron\proyectos\PROYECTO_FINAL\previos a limpieza\france_df.csv'
belgium_csv_path = r'C:\Users\VANT\iron\proyectos\PROYECTO_FINAL\previos a limpieza\belgium_df.csv'
netherlands_csv_path = r'C:\Users\VANT\iron\proyectos\PROYECTO_FINAL\previos a limpieza\netherlands_df.csv'
luxembourg_csv_path = r'C:\Users\VANT\iron\proyectos\PROYECTO_FINAL\previos a limpieza\luxembourg_df.csv'
austria_csv_path = r'C:\Users\VANT\iron\proyectos\PROYECTO_FINAL\previos a limpieza\austria_df.csv'

# Read each CSV file into a new DataFrame
spain_df = pd.read_csv(spain_csv_path)
germany_df = pd.read_csv(germany_csv_path)
italy_df = pd.read_csv(italy_csv_path)
france_df = pd.read_csv(france_csv_path)
belgium_df = pd.read_csv(belgium_csv_path)
netherlands_df = pd.read_csv(netherlands_csv_path)
luxembourg_df = pd.read_csv(luxembourg_csv_path)
austria_df = pd.read_csv(austria_csv_path)

# %%
germany_df
# Out:
#                                                   make       price    mileage  \
# 0    BMW 118 \ni 1.Hand DigiCockpit Sitzheizung Spu...  € 24,400.-  21,800 km
# 1               BMW 118 \ni Advantage DAB Tempomat PDC  € 20,890.-  11,611 km
# 2      BMW 118 \ni ADVANTAGE WLAN NAVI GRA SHZ PDC ALU  € 21,490.-  27,109 km
# 3             BMW 116 \ni Live Cockpit Navi LED AHK LM  € 23,780.-   8,800 km
# 4     BMW 118 \ni Advantage Navi PDC Wireless Charging  € 20,990.-  17,760 km
# ..                                                 ...         ...        ...
# 233  BMW 118 \ni Advantage Navi Bluetooth PDC MP3 S...  € 23,840.-  12,564 km
# 234          BMW 118 \ni Sport Line LED/AppCon/17 Zoll  € 22,950.-  25,990 km
# 235  BMW 118 \ni Sport Line LED WLAN Tempomat Klima...  € 23,439.-  24,900 km
# 236       BMW 118 \ni PDC HIFI Lederlenkrad MF Lenkrad  € 23,840.-  22,150 km
# 237  BMW 118 \ni PDC/DAB+/Bluetooth/SHZ PDC/DAB+/Bl...  € 19,727.-  24,548 km
#
#        gear      fuel               hp
# 0    Manual  Gasoline  100 kW (136 hp)
# 1    Manual  Gasoline  103 kW (140 hp)
# 2    Manual  Gasoline  103 kW (140 hp)
# 3    Manual  Gasoline   80 kW (109 hp)
# 4    Manual  Gasoline  103 kW (140 hp)
# ..      ...       ...              ...
# 233  Manual  Gasoline  103 kW (140 hp)
# 234  Manual  Gasoline  103 kW (140 hp)
# 235  Manual  Gasoline  103 kW (140 hp)
# 236  Manual  Gasoline  103 kW (140 hp)
# 237  Manual  Gasoline  103 kW (140 hp)
#
# [238 rows x 6 columns]

# %%
germany_df['make'] = germany_df['make'].str.extract(r'(BMW)', expand=False)

# %%
spain_df
# Out:
#                                              make       price    mileage  \
# 0              BMW 118 \ni 5p. Business Advantage  € 25,900.-  13,900 km
# 1           BMW 118 \n118i 5p. Business Advantage  € 29,990.-       - km
# 2                    BMW 118 \n118i 5p. Advantage  € 28,540.-       - km
# 3   BMW 118 \nbenzina Serie 1 (F40) 5p. Advantage  € 25,700.-  14,200 km
# 4                          BMW 118 \ni 5p. Msport  € 27,900.-  14,000 km
# ..                                            ...         ...        ...
# 67                    BMW 118 \nRISERVATA REBECCA  € 10,990.-  26,672 km
# 68                   BMW 118 \ni M SPORT LED NAVI  € 21,900.-  27,500 km
# 69           BMW 116 \ni Advantage 5p VARI COLORI  € 16,900.-  21,300 km
# 70                  BMW 116 \ni ADVANTAGE BENZINA  € 21,900.-   9,500 km
# 71          BMW 118 \n118i 5p. Business Advantage  € 19,900.-  27,761 km
#
#       gear      fuel               hp
# 0   Manual  Gasoline  103 kW (140 hp)
# 1   Manual  Gasoline  100 kW (136 hp)
# 2   Manual  Gasoline  100 kW (136 hp)
# 3   Manual  Gasoline  103 kW (140 hp)
# 4   Manual  Gasoline  100 kW (136 hp)
# ..     ...       ...              ...
# 67  Manual  Gasoline  105 kW (143 hp)
# 68  Manual  Gasoline  100 kW (136 hp)
# 69  Manual  Gasoline   80 kW (109 hp)
# 70  Manual  Gasoline   80 kW (109 hp)
# 71  Manual  Gasoline  103 kW (140 hp)
#
# [72 rows x 6 columns]

# %%
spain_df['hp'] = spain_df['hp'].str.extract(r'(\d+) hp')

# %%
spain_df
# Out:
#                                              make       price    mileage  \
# 0              BMW 118 \ni 5p. Business Advantage  € 25,900.-  13,900 km
# 1           BMW 118 \n118i 5p. Business Advantage  € 29,990.-       - km
# 2                    BMW 118 \n118i 5p. Advantage  € 28,540.-       - km
# 3   BMW 118 \nbenzina Serie 1 (F40) 5p. Advantage  € 25,700.-  14,200 km
# 4                          BMW 118 \ni 5p. Msport  € 27,900.-  14,000 km
# ..                                            ...         ...        ...
# 67                    BMW 118 \nRISERVATA REBECCA  € 10,990.-  26,672 km
# 68                   BMW 118 \ni M SPORT LED NAVI  € 21,900.-  27,500 km
# 69           BMW 116 \ni Advantage 5p VARI COLORI  € 16,900.-  21,300 km
# 70                  BMW 116 \ni ADVANTAGE BENZINA  € 21,900.-   9,500 km
# 71          BMW 118 \n118i 5p. Business Advantage  € 19,900.-  27,761 km
#
#       gear      fuel   hp
# 0   Manual  Gasoline  140
# 1   Manual  Gasoline  136
# 2   Manual  Gasoline  136
# 3   Manual  Gasoline  140
# 4   Manual  Gasoline  136
# ..     ...       ...  ...
# 67  Manual  Gasoline  143
# 68  Manual  Gasoline  136
# 69  Manual  Gasoline  109
# 70  Manual  Gasoline  109
# 71  Manual  Gasoline  140
#
# [72 rows x 6 columns]

# %%
spain_df['price'] = spain_df['price'].str.replace(r'\.-', '', regex=True)

# %%
spain_df
# Out:
#                                              make     price    mileage  \
# 0              BMW 118 \ni 5p. Business Advantage  € 25,900  13,900 km
# 1           BMW 118 \n118i 5p. Business Advantage  € 29,990       - km
# 2                    BMW 118 \n118i 5p. Advantage  € 28,540       - km
# 3   BMW 118 \nbenzina Serie 1 (F40) 5p. Advantage  € 25,700  14,200 km
# 4                          BMW 118 \ni 5p. Msport  € 27,900  14,000 km
# ..                                            ...       ...        ...
# 67                    BMW 118 \nRISERVATA REBECCA  € 10,990  26,672 km
# 68                   BMW 118 \ni M SPORT LED NAVI  € 21,900  27,500 km
# 69           BMW 116 \ni Advantage 5p VARI COLORI  € 16,900  21,300 km
# 70                  BMW 116 \ni ADVANTAGE BENZINA  € 21,900   9,500 km
# 71          BMW 118 \n118i 5p. Business Advantage  € 19,900  27,761 km
#
#       gear      fuel   hp
# 0   Manual  Gasoline  140
# 1   Manual  Gasoline  136
# 2   Manual  Gasoline  136
# 3   Manual  Gasoline  140
# 4   Manual  Gasoline  136
# ..     ...       ...  ...
# 67  Manual  Gasoline  143
# 68  Manual  Gasoline  136
# 69  Manual  Gasoline  109
# 70  Manual  Gasoline  109
# 71  Manual  Gasoline  140
#
# [72 rows x 6 columns]

# %%
spain_df['model'] = spain_df['make'].str.split('\n').str[1]

# %%
spain_df
# Out:
#                                              make     price    mileage  \
# 0              BMW 118 \ni 5p. Business Advantage  € 25,900  13,900 km
# 1           BMW 118 \n118i 5p. Business Advantage  € 29,990       - km
# 2                    BMW 118 \n118i 5p. Advantage  € 28,540       - km
# 3   BMW 118 \nbenzina Serie 1 (F40) 5p. Advantage  € 25,700  14,200 km
# 4                          BMW 118 \ni 5p. Msport  € 27,900  14,000 km
# ..                                            ...       ...        ...
# 67                    BMW 118 \nRISERVATA REBECCA  € 10,990  26,672 km
# 68                   BMW 118 \ni M SPORT LED NAVI  € 21,900  27,500 km
# 69           BMW 116 \ni Advantage 5p VARI COLORI  € 16,900  21,300 km
# 70                  BMW 116 \ni ADVANTAGE BENZINA  € 21,900   9,500 km
# 71          BMW 118 \n118i 5p. Business Advantage  € 19,900  27,761 km
#
#       gear      fuel   hp                                model
# 0   Manual  Gasoline  140             i 5p. Business Advantage
# 1   Manual  Gasoline  136          118i 5p. Business Advantage
# 2   Manual  Gasoline  136                   118i 5p. Advantage
# 3   Manual  Gasoline  140  benzina Serie 1 (F40) 5p. Advantage
# 4   Manual  Gasoline  136                         i 5p. Msport
# ..     ...       ...  ...                                  ...
# 67  Manual  Gasoline  143                    RISERVATA REBECCA
# 68  Manual  Gasoline  136                   i M SPORT LED NAVI
# 69  Manual  Gasoline  109           i Advantage 5p VARI COLORI
# 70  Manual  Gasoline  109                  i ADVANTAGE BENZINA
# 71  Manual  Gasoline  140          118i 5p. Business Advantage
#
# [72 rows x 7 columns]

# %%
spain_df['model'] = spain_df['model'].str.replace(r'(\d+i).*', r'118i', regex=True)

# %%
spain_df
# Out:
#                                              make     price    mileage  \
# 0              BMW 118 \ni 5p. Business Advantage  € 25,900  13,900 km
# 1           BMW 118 \n118i 5p. Business Advantage  € 29,990       - km
# 2                    BMW 118 \n118i 5p. Advantage  € 28,540       - km
# 3   BMW 118 \nbenzina Serie 1 (F40) 5p. Advantage  € 25,700  14,200 km
# 4                          BMW 118 \ni 5p. Msport  € 27,900  14,000 km
# ..                                            ...       ...        ...
# 67                    BMW 118 \nRISERVATA REBECCA  € 10,990  26,672 km
# 68                   BMW 118 \ni M SPORT LED NAVI  € 21,900  27,500 km
# 69           BMW 116 \ni Advantage 5p VARI COLORI  € 16,900  21,300 km
# 70                  BMW 116 \ni ADVANTAGE BENZINA  € 21,900   9,500 km
# 71          BMW 118 \n118i 5p. Business Advantage  € 19,900  27,761 km
#
#       gear      fuel   hp                                model
# 0   Manual  Gasoline  140             i 5p. Business Advantage
# 1   Manual  Gasoline  136                                 118i
# 2   Manual  Gasoline  136                                 118i
# 3   Manual  Gasoline  140  benzina Serie 1 (F40) 5p. Advantage
# 4   Manual  Gasoline  136                         i 5p. Msport
# ..     ...       ...  ...                                  ...
# 67  Manual  Gasoline  143                    RISERVATA REBECCA
# 68  Manual  Gasoline  136                   i M SPORT LED NAVI
# 69  Manual  Gasoline  109           i Advantage 5p VARI COLORI
# 70  Manual  Gasoline  109                  i ADVANTAGE BENZINA
# 71  Manual  Gasoline  140                                 118i
#
# [72 rows x 7 columns]

# %%
spain_df = spain_df[spain_df['model'].str.contains('118i', case=False, regex=True)]
spain_df
# Out:
#                                                 make     price    mileage  \
# 1              BMW 118 \n118i 5p. Business Advantage  € 29,990       - km
# 2                       BMW 118 \n118i 5p. Advantage  € 28,540       - km
# 5                               BMW 118 \n118i 136cv  € 25,670  17,700 km
# 7                       BMW 118 \n118i 5p. Advantage  € 28,800       - km
# 9            BMW 118 \n118I BUSINESS ADVANTAGE 136CV  € 29,600  11,578 km
# 10             BMW 118 \n118i 5p. Business Advantage  € 29,990       - km
# 14                      BMW 118 \n118i 5p. Advantage  € 28,540       - km
# 18             BMW 118 \n118i 5p. Business Advantage  € 20,900  22,300 km
# 20                      BMW 118 \n118i 5p. Advantage  € 28,800       - km
# 21             BMW 118 \n118i 5p. Business Advantage  € 29,990       - km
# 22                              BMW 118 \n118i Sport  € 25,900  25,019 km
# 23                       BMW 118 \n118i Msport 140cv  € 29,000  21,000 km
# 24                          BMW 118 \n118i 5p. Urban  € 21,500  26,300 km
# 27                      BMW 118 \n118i 5p. Advantage  € 28,540       - km
# 28       BMW 118 \n(F40) 118i 5p. Business Advantage  € 25,400  29,982 km
# 30              BMW 118 \n118i LCI 5p Msport M-sport  € 21,900  29,552 km
# 31                      BMW 118 \n118i 5p. Advantage  € 28,800       - km
# 33        BMW 118 \n118i 5p. Business Advantage Navi  € 24,900  28,000 km
# 34                         BMW 118 \n118i 5p. Msport  € 24,900  22,000 km
# 35        BMW 118 \n118i 5p. Business Advantage Navi  € 24,900  23,700 km
# 37             BMW 118 \n118i 5p. Business Advantage  € 29,990       - km
# 38                      BMW 118 \n118i 5p. Advantage  € 28,540       - km
# 40                  BMW 116 \nbenzina 116i Advantage  € 22,900   9,500 km
# 42                      BMW 118 \n118i 5p. Advantage  € 28,800       - km
# 43                          BMW 118 \n118i 5p. Sport  € 29,700   7,659 km
# 44                          BMW 118 \nF40 118i 140cv  € 22,800  27,200 km
# 45  BMW 118 \n5-porte 118i Business Advantage 5 port  € 29,373       - km
# 49                 BMW 116 \n116i Business Advantage  € 25,900  12,702 km
# 50                          BMW 118 \n118I ADVANTAGE  € 23,890  24,119 km
# 51                       BMW 118 \n118i Sport 140 CV  € 25,500  26,613 km
# 52             BMW 118 \n118i 5p. Business Advantage  € 23,900   9,000 km
# 53             BMW 118 \n118i 5p. Business Advantage  € 20,900  13,900 km
# 54                          BMW 116 \n116i Advantage  € 25,370  11,751 km
# 57                BMW 118 \n118i 5p. Advantage 136cv  € 27,800  21,739 km
# 60                              BMW 118 \n118i 140cv  € 20,370  29,913 km
# 62                                BMW 116 \n116i 5p.  € 25,590       - km
# 64                         BMW 118 \n118i 5p. Msport  € 23,900  29,000 km
# 71             BMW 118 \n118i 5p. Business Advantage  € 19,900  27,761 km
#
#       gear      fuel   hp                          model
# 1   Manual  Gasoline  136                           118i
# 2   Manual  Gasoline  136                           118i
# 5   Manual  Gasoline  136                           118i
# 7   Manual  Gasoline  136                           118i
# 9   Manual  Gasoline  136  118I BUSINESS ADVANTAGE 136CV
# 10  Manual  Gasoline  136                           118i
# 14  Manual  Gasoline  136                           118i
# 18  Manual  Gasoline  140                           118i
# 20  Manual  Gasoline  136                           118i
# 21  Manual  Gasoline  136                           118i
# 22  Manual  Gasoline  140                           118i
# 23  Manual  Gasoline  140                           118i
# 24  Manual  Gasoline  136                           118i
# 27  Manual  Gasoline  136                           118i
# 28  Manual  Gasoline  140                     (F40) 118i
# 30  Manual  Gasoline  136                           118i
# 31  Manual  Gasoline  136                           118i
# 33  Manual  Gasoline  136                           118i
# 34  Manual  Gasoline  140                           118i
# 35  Manual  Gasoline  136                           118i
# 37  Manual  Gasoline  136                           118i
# 38  Manual  Gasoline  136                           118i
# 40  Manual  Gasoline  109                   benzina 118i
# 42  Manual  Gasoline  136                           118i
# 43  Manual  Gasoline  136                           118i
# 44  Manual  Gasoline  140                       F40 118i
# 45  Manual  Gasoline  140                   5-porte 118i
# 49  Manual  Gasoline  109                           118i
# 50  Manual  Gasoline  140                 118I ADVANTAGE
# 51  Manual  Gasoline  136                           118i
# 52  Manual  Gasoline  140                           118i
# 53  Manual  Gasoline  140                           118i
# 54  Manual  Gasoline  109                           118i
# 57  Manual  Gasoline  136                           118i
# 60  Manual  Gasoline  140                           118i
# 62  Manual  Gasoline  109                           118i
# 64  Manual  Gasoline  140                           118i
# 71  Manual  Gasoline  140                           118i

# %%
spain_df['make'] = spain_df['make'].str.extract(r'(BMW)', expand=False)
# Out:
# C:\Users\VANT\AppData\Local\Temp\ipykernel_33772\834759142.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   
# 60                           118i
# 62                           118i
# 64                           118i
# 71                           118i

# %%
# Apply the same cleaning steps to germany_df
germany_df['hp'] = germany_df['hp'].str.extract(r'(\d+) hp')
germany_df['price'] = germany_df['price'].str.replace(r'\.-', '', regex=True)
germany_df['model'] = germany_df['make'].str.split('\n').str[1]
germany_df['model'] = germany_df['model'].str.replace(r'(\d+i).*', r'118i', regex=True)
germany_df = germany_df[germany_df['model'].str.contains('118i', case=False, regex=True)]
germany_df['make'] = germany_df['make'].str.extract(r'(BMW)', expand=False)
# Apply the same cleaning steps to italy_df
italy_df['hp'] = italy_df['hp'].str.extract(r'(\d+) hp')
italy_df['price'] = italy_df['price'].str.replace(r'\.-', '', regex=True)
italy_df['model'] = italy_df['make'].str.split('\n').str[1]
italy_df['model'] = italy_df['model'].str.replace(r'(\d+i).*', r'118i', regex=True)
italy_df = italy_df[italy_df['model'].str.contains('118i', case=False, regex=True)]

# Apply the same cleaning steps to france_df
france_df['hp'] = france_df['hp'].str.extract(r'(\d+) hp')
france_df['price'] = france_df['price'].str.replace(r'\.-', '', regex=True)
france_df['model'] = france_df['make'].str.split('\n').str[1]
france_df['model'] = france_df['model'].str.replace(r'(\d+i).*', r'118i', regex=True)
france_df = france_df[france_df['model'].str.contains('118i', case=False, regex=True)]

# Apply the same cleaning steps to belgium_df
belgium_df['hp'] = belgium_df['hp'].str.extract(r'(\d+) hp')
belgium_df['price'] = belgium_df['price'].str.replace(r'\.-', '', regex=True)
belgium_df['model'] = belgium_df['make'].str.split('\n').str[1]
belgium_df['model'] = belgium_df['model'].str.replace(r'(\d+i).*', r'118i', regex=True)
belgium_df = belgium_df[belgium_df['model'].str.contains('118i', case=False, regex=True)]

# Apply the same cleaning steps to luxembourg_df
luxembourg_df['hp'] = luxembourg_df['hp'].str.extract(r'(\d+) hp')
luxembourg_df['price'] = luxembourg_df['price'].str.replace(r'\.-', '', regex=True)
luxembourg_df['model'] = luxembourg_df['make'].str.split('\n').str[1]
luxembourg_df['model'] = luxembourg_df['model'].str.replace(r'(\d+i).*', r'118i', regex=True)
luxembourg_df = luxembourg_df[luxembourg_df['model'].str.contains('118i', case=False, regex=True)]

# Apply the same cleaning steps to austria_df
austria_df['hp'] = austria_df['hp'].str.extract(r'(\d+) hp')
austria_df['price'] = austria_df['price'].str.replace(r'\.-', '', regex=True)
austria_df['model'] = austria_df['make'].str.split('\n').str[1]
austria_df['model'] = austria_df['model'].str.replace(r'(\d+i).*', r'118i', regex=True)
austria_df = austria_df[austria_df['model'].str.contains('118i', case=False, regex=True)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 5
#       3 germany_df['price'] = germany_df['price'].str.replace(r'\.-', '', regex=True)
#       4 germany_df['model'] = germany_df['make'].str.split('\n').str[1]
# ----> 5 germany_df['model'] = germany_df['model'].str.replace(r'(\d+i).*', r'118i', regex=True)
#       6 germany_df = germany_df[germany_df['model'].str.contains('118i', case=False, regex=True)]
#       7 germany_df['make'] = germany_df['make'].str.extract(r'(BMW)', expand=False)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
#     225 # Replace the property with the accessor object. Inspired by:
#     226 # https://www.pydanny.com/cached-property.html
#     227 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     228 # NDFrame
#     229 object.__setattr__(obj, self._name, accessor_obj)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\strings\accessor.py:181, in StringMethods.__init__(self, data)
#     178 def __init__(self, data) -> None:
#     179     from pandas.core.arrays.string_ import StringDtype
# --> 181     self._inferred_dtype = self._validate(data)
#     182     self._is_categorical = is_categorical_dtype(data.dtype)
#     183     self._is_string = isinstance(data.dtype, StringDtype)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\strings\accessor.py:235, in StringMethods._validate(data)
#     232 inferred_dtype = lib.infer_dtype(values, skipna=True)
#     234 if inferred_dtype not in allowed_types:
# --> 235     raise AttributeError("Can only use .str accessor with string values!")
#     236 return inferred_dtype
#
# AttributeError: Can only use .str accessor with string values!

# %%
italy_df['make'] = italy_df['make'].str.extract(r'(BMW)', expand=False)
france_df['make'] = france_df['make'].str.extract(r'(BMW)', expand=False)
belgium_df['make'] = belgium_df['make'].str.extract(r'(BMW)', expand=False)
luxembourg_df['make'] = luxembourg_df['make'].str.extract(r'(BMW)', expand=False)
austria_df['make'] = austria_df['make'].str.extract(r'(BMW)', expand=False)

# %%
italy_df = italy_df[italy_df['mileage'].str.contains(r'\d+', na=False)]
italy_df
# Out:
#                                                  make       price    mileage  \
# 0                  BMW 118 \ni 5p. Business Advantage  € 25,900.-  13,900 km
# 3       BMW 118 \nbenzina Serie 1 (F40) 5p. Advantage  € 25,700.-  14,200 km
# 4                              BMW 118 \ni 5p. Msport  € 27,900.-  14,000 km
# 5                                BMW 118 \n118i 136cv  € 25,670.-  17,700 km
# 8   BMW 118 \nM SPORT LED 18" NAVY PRO PELLE IN AR...  € 21,300.-  24,500 km
# 9             BMW 118 \n118I BUSINESS ADVANTAGE 136CV  € 29,600.-  11,578 km
# 11  BMW 116 \ndiesel Serie 1 benzina 5p. Msport MA...  € 28,700.-  15,000 km
# 13              BMW 118 \ni Serie 1 (F40) 5p. M sport  € 29,900.-  16,500 km
# 16                 BMW 118 \ni 5p. Business Advantage  € 24,900.-  24,600 km
# 17      BMW 118 \ni F40 M SPORT * navi; led; cruise *  € 23,000.-  29,980 km
# 18              BMW 118 \n118i 5p. Business Advantage  € 20,900.-  22,300 km
# 19                BMW 118 \ndisponibilità vari colori  € 27,000.-  21,000 km
# 22                               BMW 118 \n118i Sport  € 25,900.-  25,019 km
# 23                        BMW 118 \n118i Msport 140cv  € 29,000.-  21,000 km
# 24                           BMW 118 \n118i 5p. Urban  € 21,500.-  26,300 km
# 25  BMW 118 \ni 5p. Advantage Business #NAVI#SENSO...  € 24,900.-  20,400 km
# 26              BMW 118 \ni F40 M SPORT * NAVI; LED *  € 25,000.-  21,550 km
# 28        BMW 118 \n(F40) 118i 5p. Business Advantage  € 25,400.-  29,982 km
# 29  BMW 118 \ni Msport 5 pt. 136cv - pack night - ...  € 22,500.-  30,000 km
# 30               BMW 118 \n118i LCI 5p Msport M-sport  € 21,900.-  29,552 km
# 32                 BMW 118 \ni 5p. Business Advantage  € 23,950.-  26,900 km
# 33         BMW 118 \n118i 5p. Business Advantage Navi  € 24,900.-  28,000 km
# 40  Manual  Gasoline   80 kW (109 hp)
# 41  Manual  Gasoline  100 kW (136 hp)
# 43  Manual  Gasoline  100 kW (136 hp)
# 44  Manual  Gasoline  103 kW (140 hp)
# 46  Manual  Gasoline  100 kW (136 hp)
# 47  Manual  Gasoline  100 kW (136 hp)
# 48  Manual  Gasoline  103 kW (140 hp)
# 49  Manual  Gasoline   80 kW (109 hp)
# 50  Manual  Gasoline  103 kW (140 hp)
# 51  Manual  Gasoline  100 kW (136 hp)
# 52  Manual  Gasoline  103 kW (140 hp)
# 53  Manual  Gasoline  103 kW (140 hp)
# 54  Manual  Gasoline   80 kW (109 hp)
# 55  Manual  Gasoline   80 kW (109 hp)
# 56  Manual  Gasoline  103 kW (140 hp)
# 57  Manual  Gasoline  100 kW (136 hp)
# 58  Manual  Gasoline   80 kW (109 hp)
# 59  Manual  Gasoline  100 kW (136 hp)
# 60  Manual  Gasoline  103 kW (140 hp)
# 61  Manual  Gasoline  100 kW (136 hp)
# 63  Manual  Gasoline  100 kW (136 hp)
# 64  Manual  Gasoline  103 kW (140 hp)
# 65  Manual  Gasoline  103 kW (140 hp)
# 66  Manual  Gasoline  100 kW (136 hp)
# 67  Manual  Gasoline  105 kW (143 hp)
# 68  Manual  Gasoline  100 kW (136 hp)
# 69  Manual  Gasoline   80 kW (109 hp)
# 70  Manual  Gasoline   80 kW (109 hp)
# 71  Manual  Gasoline  103 kW (140 hp)

# %%
spain_df.to_csv('spain_original_O.csv', index=False)
germany_df.to_csv('germany_original_O.csv', index=False)
italy_df.to_csv('italy_original_O.csv', index=False)
france_df.to_csv('france_original_O.csv', index=False)
belgium_df.to_csv('belgium_original_O.csv', index=False)
netherlands_df.to_csv('netherlands_original_O.csv', index=False)
luxembourg_df.to_csv('luxembourg_original_O.csv', index=False)
austria_df.to_csv('austria_original.csv_O', index=False)

# %%
belgium_df
# Out:
#                                                  make       price    mileage  \
# 0                  BMW 118 \ni 5p. Business Advantage  € 25,900.-  13,900 km
# 3       BMW 118 \nbenzina Serie 1 (F40) 5p. Advantage  € 25,700.-  14,200 km
# 4                              BMW 118 \ni 5p. Msport  € 27,900.-  14,000 km
# 5                                BMW 118 \n118i 136cv  € 25,670.-  17,700 km
# 8   BMW 118 \nM SPORT LED 18" NAVY PRO PELLE IN AR...  € 21,300.-  24,500 km
# 9             BMW 118 \n118I BUSINESS ADVANTAGE 136CV  € 29,600.-  11,578 km
# 11  BMW 116 \ndiesel Serie 1 benzina 5p. Msport MA...  € 28,700.-  15,000 km
# 13              BMW 118 \ni Serie 1 (F40) 5p. M sport  € 29,900.-  16,500 km
# 16                 BMW 118 \ni 5p. Business Advantage  € 24,900.-  24,600 km
# 17      BMW 118 \ni F40 M SPORT * navi; led; cruise *  € 23,000.-  29,980 km
# 18              BMW 118 \n118i 5p. Business Advantage  € 20,900.-  22,300 km
# 19                BMW 118 \ndisponibilità vari colori  € 27,000.-  21,000 km
# 22                               BMW 118 \n118i Sport  € 25,900.-  25,019 km
