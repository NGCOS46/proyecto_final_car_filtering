# %%
import pandas as pd

# %%
austria_df = pd.read_csv("austria_auto.csv")
belgium_df = pd.read_csv("belgium_auto.csv")
france_df = pd.read_csv("france_auto.csv")
germany_df = pd.read_csv("germany_auto.csv")
italy_df = pd.read_csv("italy_auto.csv")
luxembourg_df = pd.read_csv("luxembourg_auto.csv")
netherlands_df = pd.read_csv("netherlands_auto.csv")

# %%
austria_df = austria_df[austria_df['mileage'].str.contains(r'\d+', na=False)]
austria_df
# Out:
#    make     price    mileage       gear      fuel   hp         model
# 0   BMW  € 29,900  29,900 km  Automatic  Gasoline  136          118i
# 1   BMW  € 29,900  10,300 km  Automatic  Gasoline  136      F40 118i
# 3   BMW  € 28,400  20,470 km  Automatic  Gasoline  136          118i
# 4   BMW  € 27,300  12,000 km  Automatic  Gasoline  136  benzina 118i
# 10  BMW  € 29,900  14,200 km  Automatic  Gasoline  136      F40 118i
# 11  BMW  € 29,900  16,600 km  Automatic  Gasoline  136      F40 118i
# 12  BMW  € 27,900  17,073 km  Automatic  Gasoline  136          118i
# 14  BMW  € 27,900   9,000 km  Automatic  Gasoline  136          118i
# 16  BMW  € 29,900  15,400 km  Automatic  Gasoline  136      F40 118i
# 17  BMW  € 29,900  16,200 km  Automatic  Gasoline  136      F40 118i
# 18  BMW  € 29,900  10,500 km  Automatic  Gasoline  136      F40 118i
# 19  BMW  € 22,900  29,000 km  Automatic  Gasoline  136          118i
# 20  BMW  € 29,900  18,500 km  Automatic  Gasoline  136      F40 118i
# ...

# %%
belgium_df = belgium_df[belgium_df['mileage'].str.contains(r'\d+', na=False)]
belgium_df
# Out:
#    make     price    mileage       gear      fuel   hp         model
# 0   BMW  € 29,900  29,900 km  Automatic  Gasoline  109          118i
# 1   BMW  € 29,900  10,300 km  Automatic  Gasoline  109      F40 118i
# 3   BMW  € 28,400  20,470 km  Automatic  Gasoline  109          118i
# 4   BMW  € 27,300  12,000 km  Automatic  Gasoline  109  benzina 118i
# 10  BMW  € 29,900  14,200 km  Automatic  Gasoline  109      F40 118i
# 11  BMW  € 29,900  16,600 km  Automatic  Gasoline  109      F40 118i
# 12  BMW  € 27,900  17,073 km  Automatic  Gasoline  109          118i
# 14  BMW  € 27,900   9,000 km  Automatic  Gasoline  109          118i
# 16  BMW  € 29,900  15,400 km  Automatic  Gasoline  109      F40 118i
# 17  BMW  € 29,900  16,200 km  Automatic  Gasoline  109      F40 118i
# 18  BMW  € 29,900  10,500 km  Automatic  Gasoline  109      F40 118i
# 19  BMW  € 22,900  29,000 km  Automatic  Gasoline  109          118i
# 20  BMW  € 29,900  18,500 km  Automatic  Gasoline  109      F40 118i
# ...

# %%
france_df = france_df[france_df['mileage'].str.contains(r'\d+', na=False)]
france_df 
germany_df = germany_df[germany_df['mileage'].str.contains(r'\d+', na=False)]
germany_df 
italy_df = italy_df[italy_df['mileage'].str.contains(r'\d+', na=False)]
italy_df 
luxembourg_df = luxembourg_df[luxembourg_df['mileage'].str.contains(r'\d+', na=False)]
luxembourg_df
# Out:
#    make     price    mileage       gear      fuel   hp         model
# 0   BMW  € 29,900  29,900 km  Automatic  Gasoline  140          118i
# 1   BMW  € 29,900  10,300 km  Automatic  Gasoline  140      F40 118i
# 3   BMW  € 28,400  20,470 km  Automatic  Gasoline  140          118i
# 4   BMW  € 27,300  12,000 km  Automatic  Gasoline  140  benzina 118i
# 10  BMW  € 29,900  14,200 km  Automatic  Gasoline  140      F40 118i
# 11  BMW  € 29,900  16,600 km  Automatic  Gasoline  140      F40 118i
# 12  BMW  € 27,900  17,073 km  Automatic  Gasoline  140          118i
# 14  BMW  € 27,900   9,000 km  Automatic  Gasoline  140          118i
# 16  BMW  € 29,900  15,400 km  Automatic  Gasoline  140      F40 118i
# 17  BMW  € 29,900  16,200 km  Automatic  Gasoline  140      F40 118i
# 18  BMW  € 29,900  10,500 km  Automatic  Gasoline  140      F40 118i
# 19  BMW  € 22,900  29,000 km  Automatic  Gasoline  140          118i
# 20  BMW  € 29,900  18,500 km  Automatic  Gasoline  140      F40 118i
# ...

# %%
netherlands_df = netherlands_df[netherlands_df['mileage'].str.contains(r'\d+', na=False)]
netherlands_df
# Out:
#                                                  make     price    mileage  \
# 0                  BMW 118 \ni 5p. Business Advantage  € 26,900  20,000 km
# 1                         BMW 118 \n118i 136cv Msport  € 29,900  29,900 km
# 2             BMW 118 \nF40 118i Advantage 136cv auto  € 29,900  10,300 km
# 4                   BMW 118 \ni 5p. Msport automatico  € 29,900  29,000 km
# 5   BMW 118 \ni F40 M sport VirtualCock € 300 mese...  € 28,790  23,000 km
# 6                     BMW 118 \ni Sport Line LED NAVI  € 26,900  19,500 km
# 7                    BMW 118 \n118i Msport 140cv auto  € 28,400  20,470 km
# 8          BMW 118 \ni 5p. Msport Promo FINANZIAMENTO  € 29,950  11,316 km
# 9                  BMW 116 \nbenzina 116i MSport auto  € 27,300  12,000 km
# 13                            BMW 118 \ni Msport auto  € 26,900  28,271 km
# 14  BMW 118 \nSerie 1 (F20) 5p. C/AUTOM. *Pronta c...  € 19,950  19,999 km
# ...

# %%
netherlands_df['hp'] = netherlands_df['hp'].fillna(136).astype(int)

# %%
netherlands_df
# Out:
#                                                  make     price    mileage  \
# 0                  BMW 118 \ni 5p. Business Advantage  € 26,900  20,000 km
# 1                         BMW 118 \n118i 136cv Msport  € 29,900  29,900 km
# 2             BMW 118 \nF40 118i Advantage 136cv auto  € 29,900  10,300 km
# 4                   BMW 118 \ni 5p. Msport automatico  € 29,900  29,000 km
# 5   BMW 118 \ni F40 M sport VirtualCock € 300 mese...  € 28,790  23,000 km
# 6                     BMW 118 \ni Sport Line LED NAVI  € 26,900  19,500 km
# 7                    BMW 118 \n118i Msport 140cv auto  € 28,400  20,470 km
# 8          BMW 118 \ni 5p. Msport Promo FINANZIAMENTO  € 29,950  11,316 km
# 9                  BMW 116 \nbenzina 116i MSport auto  € 27,300  12,000 km
# 13                            BMW 118 \ni Msport auto  € 26,900  28,271 km
# 14  BMW 118 \nSerie 1 (F20) 5p. C/AUTOM. *Pronta c...  € 19,950  19,999 km
# ...

# %%
austria_df.to_csv("austria_auto_exported.csv", index=False)
belgium_df.to_csv("belgium_auto_exported.csv", index=False)
france_df.to_csv("france_auto_exported.csv", index=False)
germany_df.to_csv("germany_auto_exported.csv", index=False)
italy_df.to_csv("italy_auto_exported.csv", index=False)
luxembourg_df.to_csv("luxembourg_auto_exported.csv", index=False)
netherlands_df.to_csv("netherlands_auto_exported.csv", index=False)
